# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from glob import glob

# %%
from data.util import world_2_voxel,load_ct

# %%
img,_,_=load_ct('/home/x/data/datasets/tianchi/train/LKDS-00003.mhd')

# %%
world=np.array([[-112.8,170.8,209],[116,179,243]])
voxel=world_2_voxel(world,'LKDS-00877')
voxel
# Out:
# array([[ 108.06860912,  384.00013393,  230.04      ],
#        [ 610.12135565,  401.99328306,  264.04      ]])

# %%
plt.imshow(img[264],cmap='gray')

# %%
index=264
plt.figure(2)
plt.subplot(1,2,1)
plt.imshow(img[index],cmap='gray')
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(1000*mask[index]+0.1*img[index],cmap='gray')
